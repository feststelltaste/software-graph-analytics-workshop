# %% [markdown]
# # jQAssistant Code Smell Cheat Sheet
# Hints for local use:
#
# * Local install: https://github.com/JavaOnAutobahn/spring-petclinic
# * jQAssistant documentation (Java): https://jqassistant.github.io/jqassistant/doc/1.11.1/manual/#java-plugin

# %% [markdown]
# ## Setup Neo4j graph database connection
# Load Cypher Extension for Jupyter

# %%
# %reload_ext cypher
# %env NEO4J_URL=http://neo4j:neo4j@localhost:7474/db/data
# Out:
# env: NEO4J_URL=http://neo4j:neo4j@localhost:7474/db/data

# %% [markdown]
# ## Getting familiar with the Cypher

# %% [markdown]
# ### List five classes

# %%
# %%cypher
# MATCH (t:Class)
# RETURN t.name
# LIMIT 5
# Out:
# 5 rows affected.
# [['BaseEntity'], ['NamedEntity'], ['Owner'], ['Person'], ['Pet']]

# %% [markdown]
# ### List classes and their methods

# %%
# %%cypher
# MATCH (t:Class)-[:DECLARES]->(m:Method)
# RETURN t.name, m.name
# LIMIT 5
# Out:
# 5 rows affected.
# [['BaseEntity', 'setId'],
#  ['BaseEntity', 'getId'],
#  ['BaseEntity', 'isNew'],
#  ['BaseEntity', '<init>'],
#  ['NamedEntity', 'setName']]

# %% [markdown]
# ### List classes with the most methods

# %%
# %%cypher
# MATCH
#   (t:Type)-[:DECLARES]->(m:Method)
# RETURN t.fqn as type, COUNT(m) as methods
# ORDER BY methods DESC
# LIMIT 10
# Out:
# 10 rows affected.
# [['org.springframework.samples.petclinic.model.Owner', 21],
#  ['org.springframework.samples.petclinic.model.Pet', 16],
#  ['org.springframework.samples.petclinic.web.OwnerControllerTests', 13],
#  ['org.springframework.samples.petclinic.service.AbstractClinicServiceTests',
#   12],
#  ['org.springframework.samples.petclinic.service.ClinicServiceImpl', 11],
#  ['org.springframework.samples.petclinic.model.Vet', 11],
#  ['org.springframework.samples.petclinic.repository.jdbc.JdbcPet', 10],
#  ['org.springframework.samples.petclinic.model.Visit', 10],
#  ['org.springframework.samples.petclinic.web.OwnerController', 9],
#  ['org.springframework.samples.petclinic.service.ClinicService', 9]]

# %% [markdown]
# ### Methods of a specific class

# %%
# %%cypher
# MATCH
#   (t:Type {name: "Pet"})-[:DECLARES]->(m:Method)
# RETURN t.fqn as type, m.signature as Methods
# Out:
# 16 rows affected.
# [['org.springframework.samples.petclinic.model.Pet',
#   'void setName(java.lang.String)'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'void setVisitsInternal(java.util.Set)'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'java.util.List getVisits()'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'java.lang.Integer getId()'],
#  ['org.springframework.samples.petclinic.model.Pet', 'boolean isNew()'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'void setOwner(org.springframework.samples.petclinic.model.Owner)'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'java.util.Set getVisitsInternal()'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'org.springframework.samples.petclinic.model.Owner getOwner()'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'void setType(org.springframework.samples.petclinic.repository.PetType)'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'void setBirthDate(org.joda.time.LocalDate)'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'void setId(java.lang.Integer)'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'java.lang.String getName()'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'org.springframework.samples.petclinic.repository.PetType getType()'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'org.joda.time.LocalDate getBirthDate()'],
#  ['org.springframework.samples.petclinic.model.Pet',
#   'void addVisit(org.springframework.samples.petclinic.model.Visit)'],
#  ['org.springframework.samples.petclinic.model.Pet', 'void <init>()']]

# %% [markdown]
# ### List biggest classes

# %%
# %%cypher
# MATCH
#   (t:Type)-[:DECLARES]->(m:Method)
# RETURN t.fqn as type, SUM(m.effectiveLineCount) as LOC
# ORDER BY LOC DESC
# LIMIT 10
# Out:
# 10 rows affected.
# [['org.springframework.samples.petclinic.web.OwnerControllerTests', 95],
#  ['org.springframework.samples.petclinic.service.AbstractClinicServiceTests',
#   91],
#  ['org.springframework.samples.petclinic.web.PetControllerTests', 52],
#  ['org.springframework.samples.petclinic.repository.jdbc.JdbcOwnerRepositoryImpl',
#   43],
#  ['org.springframework.samples.petclinic.web.OwnerController', 40],
#  ['org.springframework.samples.petclinic.model.Owner', 40],
#  ['org.springframework.samples.petclinic.repository.jdbc.JdbcPetRepositoryImpl',
#   33],
#  ['org.springframework.samples.petclinic.web.PetController', 32],
#  ['org.springframework.samples.petclinic.web.VetControllerTests', 31],
#  ['org.springframework.samples.petclinic.repository.jdbc.JdbcVisitRepositoryImpl',
#   26]]

# %% [markdown]
# ## Getting familiar with the dataset

# %% [markdown]
# ### Existing labels `()`

# %%
# %%cypher
# MATCH (n)
# WITH DISTINCT labels(n) as labels
# UNWIND labels as label
# RETURN COLLECT(DISTINCT(label)) as Labels
# Out:
# 1 rows affected.
# [[['File',
#    'Project',
#    'Maven',
#    'Container',
#    'Directory',
#    'Artifact',
#    'Java',
#    'Main',
#    'Xml',
#    'Element',
#    'Attribute',
#    'Package',
#    'Root',
#    'Value',
#    'Property',
#    'Properties',
#    'Document',
#    'Namespace',
#    'Type',
#    'Annotation',
#    'Enum',
#    'Field',
#    'Member',
#    'Method',
#    'Class',
#    'Layer',
#    'Constructor',
#    'Parameter',
#    'Jpa',
#    'Entity',
#    'Primitive',
#    'Array',
#    'Interface',
#    'Repository',
#    'Spring',
#    'Component',
#    'Service',
#    'Controller',
#    'ManagedResource',
#    'ManagedAttribute',
#    'ManagedOperation',
#    'Concept',
#    'Test',
#    'Junit4',
#    'AssertJ',
#    'Assert',
#    'Text',
#    'Pom',
#    'Profile',
#    'Plugin',
#    'Configuration',
#    'ExecutionGoal',
#    'PluginExecution',
#    'Business',
#    'Subdomain',
#    'Dependent',
#    'TestReport',
#    'JUnit',
#    'BoundedContext',
#    'TechnicalAspect']]]

# %% [markdown]
# ### Existing properties

# %%
# %%cypher
# MATCH (n)
# WITH DISTINCT keys(n) as keys
# UNWIND keys as key
# RETURN COLLECT(DISTINCT(key)) as Properties
# Out:
# 1 rows affected.
# [[['groupId',
#    'version',
#    'artifactId',
#    'fqn',
#    'name',
#    'packaging',
#    'group',
#    'type',
#    'fileName',
#    'value',
#    'characterEncodingScheme',
#    'xmlVersion',
#    'standalone',
#    'xmlWellFormed',
#    'uri',
#    'prefix',
#    'md5',
#    'sourceFileName',
#    'visibility',
#    'byteCodeVersion',
#    'valid',
#    'signature',
#    'cyclomaticComplexity',
#    'abstract',
#    'lastMethodLineNumber',
#    'transient',
#    'volatile',
#    'firstLineNumber',
#    'lastLineNumber',
#    'effectiveLineCount',
#    'index',
#    'synthetic',
#    'static',
#    'final',
#    'id',
#    'status',
#    'inherited',
#    'phase',
#    'releasesChecksumPolicy',
#    'releasesEnabled',
#    'releasesUpdatePolicy',
#    'snapshotsChecksumPolicy',
#    'snapshotsEnabled',
#    'snapshotsUpdatePolicy',
#    'layout',
#    'url']]]

# %% [markdown]
# ### Existing relationships

# %%
# %%cypher
# MATCH ()-[r]-()
# WITH DISTINCT type(r) as rels_type
# RETURN COLLECT(DISTINCT(rels_type)) as RelationshipTypes
# Out:
# 1 rows affected.
# [[['CONTAINS',
#    'HAS_EFFECTIVE_MODEL',
#    'HAS_MODEL',
#    'CREATES',
#    'DECLARES_DEPENDENCY',
#    'DEPENDS_ON',
#    'MANAGES_DEPENDENCY',
#    'REQUIRES',
#    'DESCRIBES',
#    'HAS_ATTRIBUTE',
#    'OF_NAMESPACE',
#    'HAS_SIBLING',
#    'HAS_ELEMENT',
#    'HAS_LAST_CHILD',
#    'HAS_FIRST_CHILD',
#    'DECLARES_NAMESPACE',
#    'HAS_ROOT_ELEMENT',
#    'HAS',
#    'IS_A',
#    'BELONGS_TO',
#    'IMPLEMENTS',
#    'DECLARES',
#    'EXTENDS',
#    'ANNOTATED_BY',
#    'OF_TYPE',
#    'RETURNS',
#    'IS',
#    'DEFINES_DEPENDENCY',
#    'READS',
#    'WRITES',
#    'INVOKES',
#    'THROWS',
#    'USES',
#    'HAS_TEXT',
#    'HAS_PROFILE',
#    'USES_PLUGIN',
#    'HAS_PROPERTY',
#    'IS_ARTIFACT',
#    'HAS_CONFIGURATION',
#    'HAS_EXECUTION',
#    'HAS_GOAL',
#    'MANAGES_PLUGIN',
#    'HAS_REPOSITORY']]]

# %% [markdown]
# ### Elements of types in Java

# %% [markdown]
# #### Java type node properties

# %%
# %%cypher
# MATCH (n:Type:Java)
# WITH DISTINCT keys(n) as keys
# UNWIND keys as key
# RETURN DISTINCT key as Properties
# ORDER BY Properties
# Out:
# 11 rows affected.
# [['abstract'],
#  ['byteCodeVersion'],
#  ['fileName'],
#  ['fqn'],
#  ['lastMethodLineNumber'],
#  ['md5'],
#  ['name'],
#  ['sourceFileName'],
#  ['synthetic'],
#  ['valid'],
#  ['visibility']]

# %% [markdown]
# #### Java type node relationships

# %%
# %%cypher
# MATCH (:Type:Java)-[r]-()
# WITH DISTINCT type(r) as rels_type
# RETURN DISTINCT(rels_type) as RelationshipTypes
# Out:
# 14 rows affected.
# [['IS_A'],
#  ['BELONGS_TO'],
#  ['CONTAINS'],
#  ['IMPLEMENTS'],
#  ['DECLARES'],
#  ['DEPENDS_ON'],
#  ['EXTENDS'],
#  ['ANNOTATED_BY'],
#  ['OF_TYPE'],
#  ['RETURNS'],
#  ['REQUIRES'],
#  ['THROWS'],
#  ['USES'],
#  ['IS']]

# %% [markdown]
# #### Java type neighbour nodes

# %%
# %%cypher
# MATCH (:Type:Java)-[]-(n)
# WITH DISTINCT labels(n) as labels
# UNWIND labels as label
# RETURN COLLECT(DISTINCT(label)) as Labels
# Out:
# 1 rows affected.
# [[['Business',
#    'TechnicalAspect',
#    'Subdomain',
#    'File',
#    'Artifact',
#    'Maven',
#    'Container',
#    'Directory',
#    'Java',
#    'Main',
#    'Package',
#    'Type',
#    'Member',
#    'Method',
#    'Value',
#    'Annotation',
#    'Class',
#    'Spring',
#    'Component',
#    'Controller',
#    'Repository',
#    'Interface',
#    'ManagedResource',
#    'Service',
#    'Parameter',
#    'Constructor',
#    'Field',
#    'Enum',
#    'Jpa',
#    'Entity',
#    'Layer',
#    'Primitive',
#    'Test',
#    'Junit4',
#    'ManagedAttribute',
#    'ManagedOperation',
#    'BoundedContext',
#    'Root',
#    'AssertJ',
#    'Assert']]]

# %% [markdown]
# #### Java type neighbour relationships with nodes

# %%
# %%cypher
# MATCH (:Type:Java)-[r]-(n)
# WITH DISTINCT labels(n) as node_labels, type(r) as rel_types
# UNWIND node_labels as node_label
# RETURN DISTINCT rel_types as Relationship, node_label as Nodes
# ORDER BY Relationship
# Out:
# 114 rows affected.
# [['ANNOTATED_BY', 'Value'],
#  ['ANNOTATED_BY', 'Java'],
#  ['ANNOTATED_BY', 'Annotation'],
#  ['BELONGS_TO', 'Business'],
#  ['BELONGS_TO', 'Subdomain'],
#  ['BELONGS_TO', 'BoundedContext'],
#  ['CONTAINS', 'File'],
#  ['CONTAINS', 'Artifact'],
#  ['CONTAINS', 'Maven'],
#  ['CONTAINS', 'Container'],
#  ['CONTAINS', 'Directory'],
#  ['CONTAINS', 'Java'],
#  ['CONTAINS', 'Main'],
#  ['CONTAINS', 'Package'],
#  ['CONTAINS', 'Layer'],
#  ['CONTAINS', 'Root'],
#  ['DECLARES', 'Java'],
#  ['DECLARES', 'Member'],
#  ['DECLARES', 'Method'],
#  ['DECLARES', 'Constructor'],
#  ['DECLARES', 'Field'],
#  ['DECLARES', 'File'],
#  ['DECLARES', 'Type'],
#  ['DECLARES', 'Repository'],
#  ['DECLARES', 'Class'],
#  ['DECLARES', 'Spring'],
#  ['DECLARES', 'Component'],
#  ['DECLARES', 'ManagedAttribute'],
#  ['DECLARES', 'ManagedOperation'],
#  ['DECLARES', 'Test'],
#  ['DECLARES', 'Junit4'],
#  ['DECLARES', 'AssertJ'],
#  ['DECLARES', 'Assert'],
#  ['DEPENDS_ON', 'File'],
#  ['DEPENDS_ON', 'Type'],
#  ['DEPENDS_ON', 'Java'],
#  ['DEPENDS_ON', 'Class'],
#  ['DEPENDS_ON', 'Spring'],
#  ['DEPENDS_ON', 'Component'],
#  ['DEPENDS_ON', 'Controller'],
#  ['DEPENDS_ON', 'Repository'],
#  ['DEPENDS_ON', 'Interface'],
#  ['DEPENDS_ON', 'ManagedResource'],
#  ['DEPENDS_ON', 'Annotation'],
#  ['DEPENDS_ON', 'Service'],
#  ['DEPENDS_ON', 'Jpa'],
#  ['DEPENDS_ON', 'Entity'],
#  ['EXTENDS', 'File'],
#  ['EXTENDS', 'Type'],
#  ['EXTENDS', 'Java'],
#  ['EXTENDS', 'Class'],
#  ['EXTENDS', 'Spring'],
#  ['EXTENDS', 'Component'],
#  ['EXTENDS', 'Controller'],
#  ['EXTENDS', 'Interface'],
#  ['EXTENDS', 'Repository'],
#  ['EXTENDS', 'Annotation'],
#  ['EXTENDS', 'Service'],
#  ['EXTENDS', 'ManagedResource'],
#  ['EXTENDS', 'Jpa'],
#  ['EXTENDS', 'Entity'],
#  ['IMPLEMENTS', 'File'],
#  ['IMPLEMENTS', 'Type'],
#  ['IMPLEMENTS', 'Java'],
#  ['IMPLEMENTS', 'Annotation'],
#  ['IMPLEMENTS', 'Interface'],
#  ['IMPLEMENTS', 'Repository'],
#  ['IMPLEMENTS', 'Class'],
#  ['IMPLEMENTS', 'Spring'],
#  ['IMPLEMENTS', 'Component'],
#  ['IMPLEMENTS', 'Service'],
#  ['IS', 'Value'],
#  ['IS', 'Class'],
#  ['IS_A', 'Business'],
#  ['IS_A', 'TechnicalAspect'],
#  ['OF_TYPE', 'Java'],
#  ['OF_TYPE', 'Parameter'],
#  ['OF_TYPE', 'Value'],
#  ['OF_TYPE', 'Annotation'],
#  ['OF_TYPE', 'Enum'],
#  ['OF_TYPE', 'Primitive'],
#  ['OF_TYPE', 'Field'],
#  ['OF_TYPE', 'Member'],
#  ['REQUIRES', 'File'],
#  ['REQUIRES', 'Artifact'],
#  ['REQUIRES', 'Maven'],
#  ['REQUIRES', 'Container'],
#  ['REQUIRES', 'Directory'],
#  ['REQUIRES', 'Java'],
#  ['REQUIRES', 'Main'],
#  ['RETURNS', 'Java'],
#  ['RETURNS', 'Member'],
#  ['RETURNS', 'Method'],
#  ['RETURNS', 'Test'],
#  ['RETURNS', 'Junit4'],
#  ['RETURNS', 'Constructor'],
#  ['RETURNS', 'Spring'],
#  ['RETURNS', 'ManagedAttribute'],
#  ['RETURNS', 'ManagedOperation'],
#  ['THROWS', 'Java'],
#  ['THROWS', 'Member'],
#  ['THROWS', 'Method'],
#  ['THROWS', 'Test'],
#  ['THROWS', 'Junit4'],
#  ['USES', 'File'],
#  ['USES', 'Type'],
#  ['USES', 'Repository'],
#  ['USES', 'Java'],
#  ['USES', 'Class'],
#  ['USES', 'Spring'],
#  ['USES', 'Component'],
#  ['USES', 'Service'],
#  ['USES', 'Interface'],
#  ['USES', 'Controller']]

# %% [markdown]
# ### Elements of methods in Java

# %% [markdown]
# #### Java method node properties

# %%
# %%cypher
# MATCH (m:Method:Java)-[]-()
# WITH DISTINCT keys(m) as keys
# UNWIND keys as key
# RETURN DISTINCT key as Properties
# ORDER BY Properties
# Out:
# 10 rows affected.
# [['abstract'],
#  ['cyclomaticComplexity'],
#  ['effectiveLineCount'],
#  ['firstLineNumber'],
#  ['lastLineNumber'],
#  ['name'],
#  ['signature'],
#  ['static'],
#  ['synthetic'],
#  ['visibility']]

# %% [markdown]
# #### Java method node relationships

# %%
# %%cypher
# MATCH (:Method:Java)-[r]-()
# WITH DISTINCT type(r) as rels_type
# RETURN DISTINCT(rels_type) as RelationshipTypes
# Out:
# 8 rows affected.
# [['DECLARES'],
#  ['RETURNS'],
#  ['INVOKES'],
#  ['READS'],
#  ['WRITES'],
#  ['HAS'],
#  ['ANNOTATED_BY'],
#  ['THROWS']]

# %% [markdown]
# ## Listing possible code smells

# %% [markdown]
# ### Statische, geschriebene Variablen

# %%
# %%cypher
# MATCH (c:Class)-[:DECLARES]->(f:Field)<-[w:WRITES]-(m:Method)
# WHERE
#     EXISTS(f.static) AND NOT EXISTS(f.final)
# RETURN
#     c.name as InClass,
#     m.name as theMethod,
#     w.lineNumber as writesInLine,
#     f.name as toStaticField
# Out:
# 3 rows affected.
# [['OwnerController', 'processFindForm', 112, 'ownersIndexes'],
#  ['OwnerController', 'processFindForm', 112, 'ownersIndexes'],
#  ['BrokenSingleton', 'getInstance', 11, 'INSTANCE']]

# %% [markdown]
# ### Add subdomain information to types

# %%
# %%cypher
#
# UNWIND [
#         { name: "Clinic" },
#         { name: "Owner" },
#         { name: "Person" },
#         { name: "Pet" },
#         { name: "Specialty" },
#         { name: "Vet" },
#         { name: "Visit" }
#     ]
#     AS properties
# CREATE (s:Subdomain) SET s = properties
# WITH s
#         MATCH (t:Type)
#             WHERE t.name CONTAINS s.name
#         MERGE (t)-[:BELONGS_TO]->(s)
# RETURN s.name, t.name
# LIMIT 10
# Out:
# 7 nodes created.
# 7 properties set.
# 10 relationships created.
# 7 labels added.
# [['Clinic', 'ClinicService'],
#  ['Clinic', 'ClinicServiceImpl'],
#  ['Clinic', 'AbstractClinicServiceTests'],
#  ['Clinic', 'ClinicServiceJdbcTests'],
#  ['Clinic', 'ClinicServiceJpaTests'],
#  ['Clinic', 'ClinicServiceSpringDataJpaTests'],
#  ['Owner', 'Owner'],
#  ['Owner', 'JdbcOwnerRepositoryImpl'],
#  ['Owner', 'OwnerRepository'],
#  ['Owner', 'JpaOwnerRepositoryImpl']]

# %% [markdown]
# ### Count types per Subdomain

# %%
# %%cypher
# MATCH
#   (t:Type)-[:BELONGS_TO]->(s:Subdomain)
# RETURN
#   s.name as ASubdomain,
#   COUNT(DISTINCT t) as Types
# ORDER BY Types DESC
# Out:
# 8 rows affected.
# [['crossfunctional', 19],
#  ['Pet', 17],
#  ['Vet', 9],
#  ['Visit', 9],
#  ['Owner', 7],
#  ['Clinic', 6],
#  ['Person', 1],
#  ['Specialty', 1]]

# %% [markdown]
# ### Aggregate cyclomatic complexity by Subdomains

# %%
# %%cypher
# MATCH
#   (m:Method)<-[:DECLARES]-(t:Type)-[:BELONGS_TO]->(s:Subdomain)
# RETURN
#   s.name as ASubdomain,
#   COUNT(DISTINCT t) as Types,
#   AVG(m.cyclomaticComplexity) as CC,
#   SUM(DISTINCT t.lastMethodLineNumber) as Lines
# ORDER BY CC DESC, Lines DESC
# Out:
# 8 rows affected.
# [['Owner', 7, 1.4625000000000001, 722],
#  ['crossfunctional', 17, 1.2666666666666662, 405],
#  ['Vet', 8, 1.2500000000000007, 485],
#  ['Pet', 17, 1.2345679012345672, 1100],
#  ['Visit', 8, 1.2105263157894735, 564],
#  ['Clinic', 6, 1.0, 387],
#  ['Person', 1, 1.0, 53],
#  ['Specialty', 1, 1.0, 32]]
