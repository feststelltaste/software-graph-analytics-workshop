# %% [markdown]
# # Data import

# %% [markdown]
# This is a short demonstration that shows you how you can import raw data into the Neo4j database without tools like jQAssistant (because you cannot use them in your programming language).

# %% [markdown]
# ## Import dependencies (from jdeps)

# %% [markdown]
# Import dataset

# %%
import pandas as pd

deps = pd.read_csv("data/spring_petclinic_deps.txt", names=["raw"], sep="\n")
deps.head()
# Out:
#                                                  raw
# 0            spring-petclinic-2.4.5.jar -> not found
# 1  spring-petclinic-2.4.5.jar -> /usr/lib/jvm/jav...
# 2     org.springframework.boot.loader.ClassPathIn...
# 3     org.springframework.boot.loader.ClassPathIn...
# 4     org.springframework.boot.loader.ClassPathIn...

# %% [markdown]
# Normalize data

# %%
# class entries begin with three whitespaces
deps = deps[deps['raw'].str.startswith("   ")]
# separates the source from the target
splitted = deps['raw'].str.split("->", n=1, expand=True)
# remove whitespaces from source
deps['from'] = splitted[0].str.strip()
# get the target and the artifact names
splitted_2 = splitted[1].str.split(" ", n=2)
deps['to'] = splitted_2.str[1]
deps['type'] = splitted_2.str[2].str.strip()
deps['name'] = deps['from'].str.split(".").str[-1]
deps.head()
# Out:
#                                                  raw  \
# 2     org.springframework.boot.loader.ClassPathIn...
# 3     org.springframework.boot.loader.ClassPathIn...
# 4     org.springframework.boot.loader.ClassPathIn...
# 5     org.springframework.boot.loader.ClassPathIn...
# 6     org.springframework.boot.loader.ClassPathIn...
#
#                                                 from                       to  \
# 2  org.springframework.boot.loader.ClassPathIndex...   java.io.BufferedReader
# 3  org.springframework.boot.loader.ClassPathIndex...             java.io.File
# 4  org.springframework.boot.loader.ClassPathIndex...  java.io.FileInputStream
# 5  org.springframework.boot.loader.ClassPathIndex...      java.io.IOException
# 6  org.springframework.boot.loader.ClassPathIndex...      java.io.InputStream
#
#   type                name
# 2       ClassPathIndexFile
# 3       ClassPathIndexFile
# 4       ClassPathIndexFile
# 5       ClassPathIndexFile
# 6       ClassPathIndexFile

# %% [markdown]
# Focus on core application

# %%
petclinic_deps = deps[
    (
        deps['from'].str.startswith("org.springframework.samples.petclinic") |
        deps['to'].str.startswith("org.springframework.samples.petclinic")
    )
    ].copy()
petclinic_deps.head()
# Out:
#                                                    raw  \
# 867     org.springframework.samples.petclinic.PetCl...
# 868     org.springframework.samples.petclinic.PetCl...
# 869     org.springframework.samples.petclinic.PetCl...
# 870     org.springframework.samples.petclinic.PetCl...
# 871     org.springframework.samples.petclinic.PetCl...
#
#                                                   from  \
# 867  org.springframework.samples.petclinic.PetClini...
# 868  org.springframework.samples.petclinic.PetClini...
# 869  org.springframework.samples.petclinic.PetClini...
# 870  org.springframework.samples.petclinic.PetClini...
# 871  org.springframework.samples.petclinic.PetClini...
#
#                                                     to       type  \
# 867                                    java.lang.Class
# 868                                   java.lang.Object
# 869                                   java.lang.String
# 870         org.springframework.boot.SpringApplication  not found
# 871  org.springframework.boot.autoconfigure.SpringB...  not found
#
#                      name
# 867  PetClinicApplication
# 868  PetClinicApplication
# 869  PetClinicApplication
# 870  PetClinicApplication
# 871  PetClinicApplication

# %% [markdown]
# ## Import coverage data (from JaCoCo)

# %% [markdown]
# Import dataset

# %%
coverage = pd.read_csv("data/spring_petclinic_production_coverage_data.csv")
coverage.head()
# Out:
#                                        PACKAGE                 CLASS  \
# 0        org.springframework.samples.petclinic  PetclinicInitializer
# 1  org.springframework.samples.petclinic.model           NamedEntity
# 2  org.springframework.samples.petclinic.model             Specialty
# 3  org.springframework.samples.petclinic.model               PetType
# 4  org.springframework.samples.petclinic.model                  Vets
#
#    LINE_MISSED  LINE_COVERED
# 0            0            24
# 1            1             4
# 2            0             1
# 3            0             1
# 4            4             0

# %% [markdown]
# Enrich data

# %%
coverage['lines'] = coverage.LINE_COVERED + coverage.LINE_MISSED
coverage['ratio'] = coverage.LINE_COVERED / coverage.lines
coverage.head()
# Out:
#                                        PACKAGE                 CLASS  \
# 0        org.springframework.samples.petclinic  PetclinicInitializer
# 1  org.springframework.samples.petclinic.model           NamedEntity
# 2  org.springframework.samples.petclinic.model             Specialty
# 3  org.springframework.samples.petclinic.model               PetType
# 4  org.springframework.samples.petclinic.model                  Vets
#
#    LINE_MISSED  LINE_COVERED  lines  ratio
# 0            0            24     24    1.0
# 1            1             4      5    0.8
# 2            0             1      1    1.0
# 3            0             1      1    1.0
# 4            4             0      4    0.0

# %% [markdown]
# Normalize data

# %%
coverage['fqn'] = coverage["PACKAGE"] + "." + coverage["CLASS"]
coverage.head()
# Out:
#                                        PACKAGE                 CLASS  \
# 0        org.springframework.samples.petclinic  PetclinicInitializer
# 1  org.springframework.samples.petclinic.model           NamedEntity
# 2  org.springframework.samples.petclinic.model             Specialty
# 3  org.springframework.samples.petclinic.model               PetType
# 4  org.springframework.samples.petclinic.model                  Vets
#
#    LINE_MISSED  LINE_COVERED  lines  ratio  \
# 0            0            24     24    1.0
# 1            1             4      5    0.8
# 2            0             1      1    1.0
# 3            0             1      1    1.0
# 4            4             0      4    0.0
#
#                                                  fqn
# 0  org.springframework.samples.petclinic.Petclini...
# 1  org.springframework.samples.petclinic.model.Na...
# 2  org.springframework.samples.petclinic.model.Sp...
# 3  org.springframework.samples.petclinic.model.Pe...
# 4   org.springframework.samples.petclinic.model.Vets

# %% [markdown]
# ## Import source code data

# %% [markdown]
# Import data

# %%
cloc = pd.read_csv("data/spring_petclinic_cloc.csv")[:-1].copy()
cloc.tail()
# Out:
#    language                                           filename  blank  \
# 20     Java  ./org/springframework/samples/petclinic/vet/Sp...      5
# 21     Java  ./org/springframework/samples/petclinic/visit/...      6
# 22     Java  ./org/springframework/samples/petclinic/PetCli...      5
# 23     Java  ./org/springframework/samples/petclinic/owner/...      4
# 24     Java  ./org/springframework/samples/petclinic/model/...      1
#
#     comment  code  \
# 20       20     9
# 21       31     9
# 22       21     9
# 23       18     8
# 24       18     1
#
#     github.com/AlDanial/cloc v 1.82  T=0.33 s (75.4 files/s, 4843.0 lines/s)
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN

# %% [markdown]
# Normalize data

# %%
cloc['fqn'] = cloc['filename'].str.replace("./", "", regex=False)\
                              .str.replace("/",".", regex=False)\
                              .str.replace(".java","", regex=False)
cloc.head()
# Out:
#   language                                           filename  blank  comment  \
# 0     Java  ./org/springframework/samples/petclinic/owner/...     18       31
# 1     Java  ./org/springframework/samples/petclinic/owner/...     23       33
# 2     Java  ./org/springframework/samples/petclinic/owner/...     16       20
# 3     Java  ./org/springframework/samples/petclinic/owner/...     19       22
# 4     Java  ./org/springframework/samples/petclinic/owner/...     12       31
#
#    code  \
# 0    96
# 1    94
# 2    77
# 3    71
# 4    49
#
#    github.com/AlDanial/cloc v 1.82  T=0.33 s (75.4 files/s, 4843.0 lines/s)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                  fqn
# 0  org.springframework.samples.petclinic.owner.Ow...
# 1  org.springframework.samples.petclinic.owner.Owner
# 2  org.springframework.samples.petclinic.owner.Pe...
# 3    org.springframework.samples.petclinic.owner.Pet
# 4  org.springframework.samples.petclinic.owner.Vi...

# %%
loc = cloc[['fqn', 'code', 'comment', 'blank']].dropna().copy()
loc.head()
# Out:
#                                                  fqn  code  comment  blank
# 0  org.springframework.samples.petclinic.owner.Ow...    96       31     18
# 1  org.springframework.samples.petclinic.owner.Owner    94       33     23
# 2  org.springframework.samples.petclinic.owner.Pe...    77       20     16
# 3    org.springframework.samples.petclinic.owner.Pet    71       22     19
# 4  org.springframework.samples.petclinic.owner.Vi...    49       31     12

# %% [markdown]
# # Load data into Neo4J

# %% [markdown]
# Esablish connection to Neo4j graph database

# %%
from py2neo import Graph
graph = Graph("http://localhost:7474", password="neo4j")
graph
# Out:
# Graph('http://localhost:7474')

# %% [markdown]
# Clean data from previous run

# %%
query="""
   MATCH (n:JType)
   MATCH (m:JMeasure)
   DETACH DELETE n, m
"""
graph.run(query)
# Out:
# (No data)

# %% [markdown]
# ## jdeps

# %%
petclinic_deps.head()
# Out:
#                                                    raw  \
# 867     org.springframework.samples.petclinic.PetCl...
# 868     org.springframework.samples.petclinic.PetCl...
# 869     org.springframework.samples.petclinic.PetCl...
# 870     org.springframework.samples.petclinic.PetCl...
# 871     org.springframework.samples.petclinic.PetCl...
#
#                                                   from  \
# 867  org.springframework.samples.petclinic.PetClini...
# 868  org.springframework.samples.petclinic.PetClini...
# 869  org.springframework.samples.petclinic.PetClini...
# 870  org.springframework.samples.petclinic.PetClini...
# 871  org.springframework.samples.petclinic.PetClini...
#
#                                                     to       type  \
# 867                                    java.lang.Class
# 868                                   java.lang.Object
# 869                                   java.lang.String
# 870         org.springframework.boot.SpringApplication  not found
# 871  org.springframework.boot.autoconfigure.SpringB...  not found
#
#                      name
# 867  PetClinicApplication
# 868  PetClinicApplication
# 869  PetClinicApplication
# 870  PetClinicApplication
# 871  PetClinicApplication

# %%
query="""
    UNWIND {deps_data} as dep
    CREATE
        (t:JType)
    SET
        t.fqn = dep.from,
        t.name = dep.name
    RETURN t.fqn, t.name
"""

result = graph.run(query, deps_data=petclinic_deps[['from', 'name']].drop_duplicates().to_dict(orient='records')).data()
pd.DataFrame(result).head()
# Out:
#                                                t.fqn                t.name
# 0  org.springframework.samples.petclinic.PetClini...  PetClinicApplication
# 1  org.springframework.samples.petclinic.model.Ba...            BaseEntity
# 2  org.springframework.samples.petclinic.model.Na...           NamedEntity
# 3  org.springframework.samples.petclinic.model.Pe...                Person
# 4  org.springframework.samples.petclinic.owner.Owner                 Owner

# %% [markdown]
# Create index for `fqn" for faster queries

# %%
query="""
  CREATE INDEX ON :J(fqn)
"""
graph.run(query)
# Out:
# (No data)

# %%
query="""
    UNWIND {deps_data} as dep
    MATCH (from:JType {fqn : dep.from})
    MATCH (to:JType {fqn: dep.to})
    MERGE (from)-[:DEPENDS_ON]->(to)
    RETURN from.fqn, to.fqn
"""

result = graph.run(query, deps_data=petclinic_deps.to_dict(orient='records')).data()
pd.DataFrame(result).head()
# Out:
#                                             from.fqn  \
# 0  org.springframework.samples.petclinic.model.Na...
# 1  org.springframework.samples.petclinic.model.Pe...
# 2  org.springframework.samples.petclinic.owner.Owner
# 3  org.springframework.samples.petclinic.owner.Owner
# 4  org.springframework.samples.petclinic.owner.Ow...
#
#                                               to.fqn
# 0  org.springframework.samples.petclinic.model.Ba...
# 1  org.springframework.samples.petclinic.model.Ba...
# 2  org.springframework.samples.petclinic.model.Pe...
# 3    org.springframework.samples.petclinic.owner.Pet
# 4  org.springframework.samples.petclinic.owner.Owner

# %% [markdown]
# ## JaCoCo coverage data

# %%
coverage.head()
# Out:
#                                        PACKAGE                 CLASS  \
# 0        org.springframework.samples.petclinic  PetclinicInitializer
# 1  org.springframework.samples.petclinic.model           NamedEntity
# 2  org.springframework.samples.petclinic.model             Specialty
# 3  org.springframework.samples.petclinic.model               PetType
# 4  org.springframework.samples.petclinic.model                  Vets
#
#    LINE_MISSED  LINE_COVERED  lines  ratio  \
# 0            0            24     24    1.0
# 1            1             4      5    0.8
# 2            0             1      1    1.0
# 3            0             1      1    1.0
# 4            4             0      4    0.0
#
#                                                  fqn
# 0  org.springframework.samples.petclinic.Petclini...
# 1  org.springframework.samples.petclinic.model.Na...
# 2  org.springframework.samples.petclinic.model.Sp...
# 3  org.springframework.samples.petclinic.model.Pe...
# 4   org.springframework.samples.petclinic.model.Vets

# %%
query="""
    UNWIND {coverage_data} as coverage
    MATCH (t:JType {fqn : coverage.fqn})
    MERGE (t)-[:HAS_JMEASURE]->(m)
    SET 
        m:JMeasure:JCoverage,
        m.ratio = coverage.ratio
    RETURN t.fqn as fqn, m.ratio as ratio
"""

result = graph.run(query, coverage_data=coverage.to_dict(orient='records')).data()
pd.DataFrame(result).head()
# Out:
#                                                  fqn  ratio
# 0  org.springframework.samples.petclinic.model.Na...    0.8
# 1  org.springframework.samples.petclinic.model.Ba...    1.0
# 2  org.springframework.samples.petclinic.model.Pe...    1.0

# %% [markdown]
# ## cloc data

# %%
loc.head()
# Out:
#                                                  fqn  code  comment  blank
# 0  org.springframework.samples.petclinic.owner.Ow...    96       31     18
# 1  org.springframework.samples.petclinic.owner.Owner    94       33     23
# 2  org.springframework.samples.petclinic.owner.Pe...    77       20     16
# 3    org.springframework.samples.petclinic.owner.Pet    71       22     19
# 4  org.springframework.samples.petclinic.owner.Vi...    49       31     12

# %%
query="""
    UNWIND {cloc_data} as loc
    MATCH (t:JType {fqn : loc.fqn})
    SET
        t.lines = loc.code,
        t.comments = loc.comment,
        t.blanks = loc.blank
    RETURN t.fqn, t.name, t.lines, t.comments, t.blanks
"""

result = graph.run(query, cloc_data=loc.to_dict(orient='records')).data()
pd.DataFrame(result).head()
# Out:
#                                                t.fqn           t.name  \
# 0  org.springframework.samples.petclinic.owner.Ow...  OwnerController
# 1  org.springframework.samples.petclinic.owner.Owner            Owner
# 2  org.springframework.samples.petclinic.owner.Pe...    PetController
# 3    org.springframework.samples.petclinic.owner.Pet              Pet
# 4  org.springframework.samples.petclinic.owner.Vi...  VisitController
#
#    t.lines  t.comments  t.blanks
# 0       96          31        18
# 1       94          33        23
# 2       77          20        16
# 3       71          22        19
# 4       49          31        12

# %% [markdown]
# # Check data

# %% [markdown]
# ## Validate Nodes

# %%
query="""
   MATCH (n:JType)
   RETURN n.fqn
"""

result = graph.run(query).data()
pd.DataFrame(result)
# Out:
#                                                 n.fqn
# 0   org.springframework.samples.petclinic.owner.Ow...
# 1     org.springframework.samples.petclinic.owner.Pet
# 2   org.springframework.samples.petclinic.owner.Pe...
# 3   org.springframework.samples.petclinic.owner.Pe...
# 4   org.springframework.samples.petclinic.owner.Pe...
# 5   org.springframework.samples.petclinic.owner.Pe...
# 6   org.springframework.samples.petclinic.owner.Pe...
# 7   org.springframework.samples.petclinic.owner.Vi...
# 8   org.springframework.samples.petclinic.system.C...
# 9   org.springframework.samples.petclinic.system.C...
# 10  org.springframework.samples.petclinic.system.W...
# 11  org.springframework.samples.petclinic.vet.Spec...
# 12      org.springframework.samples.petclinic.vet.Vet
# 13  org.springframework.samples.petclinic.vet.VetC...
# 14  org.springframework.samples.petclinic.vet.VetR...
# 15     org.springframework.samples.petclinic.vet.Vets
# 16  org.springframework.samples.petclinic.visit.Visit
# 17  org.springframework.samples.petclinic.visit.Vi...
# 18  org.springframework.samples.petclinic.PetClini...
# 19  org.springframework.samples.petclinic.model.Ba...
# 20  org.springframework.samples.petclinic.model.Na...
# 21  org.springframework.samples.petclinic.model.Pe...
# 22  org.springframework.samples.petclinic.owner.Owner
# 23  org.springframework.samples.petclinic.owner.Ow...

# %%
query="""
   MATCH (n:JType)-[:HAS_JMEASURE]->(m:JMeasure)
   RETURN n.fqn, n.lines, m.ratio
"""

result = graph.run(query).data()
pd.DataFrame(result)
# Out:
#                                                n.fqn  n.lines  m.ratio
# 0  org.springframework.samples.petclinic.model.Na...       18      0.8
# 1  org.springframework.samples.petclinic.model.Ba...       21      1.0
# 2  org.springframework.samples.petclinic.model.Pe...       25      1.0
